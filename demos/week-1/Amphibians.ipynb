# %%
# !mv /Users/shzh8108/Downloads/Amphibians_on_NPS_Lands_20231201.csv .

# %%
import pandas as pd

pd.set_option('display.max_columns', 50)

df = pd.read_csv("./Amphibians_on_NPS_Lands_20231201.csv")

print(len(df))

df.head()
# Out:
# 3472
#   Park_Code                                          Park_Name IM_Network  \
# 0      ABLI  Abraham Lincoln Birthplace National Historical...       CUPN
# 1      ABLI  Abraham Lincoln Birthplace National Historical...       CUPN
# 2      ABLI  Abraham Lincoln Birthplace National Historical...       CUPN
# 3      ABLI  Abraham Lincoln Birthplace National Historical...       CUPN
# 4      ABLI  Abraham Lincoln Birthplace National Historical...       CUPN
#
#   CASC_Region State     TSN    Order          Family  \
# 0          NE    KY  173520    Anura         Hylidae
# 1          NE    KY  208204  Caudata  Ambystomatidae
# 2          NE    KY  173598  Caudata  Ambystomatidae
# 3          NE    KY  173590  Caudata  Ambystomatidae
# 4          NE    KY  173591  Caudata  Ambystomatidae
#
#             Scientific_Name                                 Common_Names  \
# 0           Acris crepitans  Northern Cricket Frog, Eastern Cricket Frog
# ...

# %%
# How many species per park?

species_by_park = df.groupby('Park_Code').agg({'Scientific_Name': ['count', 'nunique']})
# Out:
#           Scientific_Name
#                     count nunique
# Park_Code
# ABLI                   30      30
# ACAD                   15      15
# AGFO                    7       7
# ALFL                   13      13
# ALPO                   25      25
# ...                   ...     ...
# YELL                    6       6
# YOSE                   13      13
# YUCH                    1       1
# YUHO                    5       5
# ZION                    7       7
#
# [286 rows x 2 columns]
